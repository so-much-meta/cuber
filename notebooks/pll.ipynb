# %%
from cuber import Cube
olls = {}
sune = "RUR'URU2R'"
antisune = "L'U'LU'L'U2L"
c = Cube(3, whiteplastic=True)
c.draw_top = True
c.top_solving = 'pll'
c.echo = False

c.reset()
c.move('x2')
c.reverse(sune)
c.move(antisune)
c.move('U2')
c.move(sune)
c.move("U'")
c.move(sune)
c.move("U'")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=288x144 at 0x7F7987EDA970>
