# %%
## To install from colab
## !pip install -q git+https://github.com/so-much-meta/cuber
from cuber import Cube
cube = Cube(3, whiteplastic=True)
cube

# %%
cube.move("RUR'U'")
# Out:
# R U R' U'

# %%
cube.move("RUR'URU2R'")
# Out:
# R U R' U R U2 R'

# %%
cube.reset()

# %%
cube.move('M')
# Out:
# M

# %%
cube.move('E')
# Out:
# E

# %%
cube.move('S')
# Out:
# S

# %%
cube.move('x')
# Out:
# x

# %%
cube.move('y')
# Out:
# y

# %%
cube.move('z')
# Out:
# z

# %%
cube.render('flat')

# %%
cube.render('front-right', 'right-back', 'flat', 'bottom-left')
