# %%
from cuber import Cube
olls = {}
sune = "RUR'URU2R'"
antisune = "L'U'LU'L'U2L"
c = Cube(3, whiteplastic=True)
c.draw_top = True
c.echo = False

c.reset()
c.move('x2')
c.reverse(sune)
olls['fish'] = c.copy()

c.reset()
c.move('x2')
c.reverse(sune)
c.reverse(sune)
olls['double-headlights'] = c.copy()

c.reverse(sune)
c.move('U2')
olls['stupid-fish'] = c.copy()

c.reset()
c.move('x2')
c.reverse(sune)
c.move('U')
c.move(sune)
c.move('U')
olls['headlights'] = c.copy()


c.reset()
c.move('x2')
c.reverse(antisune)
c.move(sune)
olls['chamelon-headlights'] = c.copy()


c.reset()
c.move('x2')
c.reverse(antisune)
c.move(sune)
c.reverse(antisune)
c.move("U")
olls['chameleon'] = c.copy()

# %%
from IPython.display import Markdown
for key, c in olls.items():
    c = c.copy()
    c.echo = False
    c.draw_front = False
    c.top_solving = 'oll'
    display(Markdown(f"# {key}"))
    display(c)
    display(Markdown(f"### ==> Move: sune = {sune}"))
    c.move(sune)
    display(c)
    display(Markdown(f"---"))
# Out:
# # fish
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893C127E50>
# ### ==> Move: sune = RUR'URU2R'
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893B44FDF0>
# ---
# # double-headlights
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893B45F730>
# ### ==> Move: sune = RUR'URU2R'
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893B735B80>
# ---
# # stupid-fish
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893B955970>
# ### ==> Move: sune = RUR'URU2R'
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893BB3D280>
# ---
# # headlights
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893BAE9B50>
# ### ==> Move: sune = RUR'URU2R'
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893C97F490>
# ---
# # chamelon-headlights
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=144x144 at 0x7F893CA16D60>
# ...
